# %% [markdown]
# # Matplotlib Library

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## simple line plot

# %%
x=[1,3,2,5,6]
y=[2,3,4,5,4]
plt.plot(x,y)
plt.show()

# %%
x=[1,3,2,5,6]
y=[2,3,4,5,4]
plt.plot(x,y,"o")
plt.show()

# %%
x=[1,3,2,5,6]
y=[2,3,4,5,4]
plt.plot(x,y,"D")
plt.show()

# %%
x=[1,3,2,5,6]
y=[2,3,4,5,4]
plt.plot(x,y,"d")
plt.show()

# %%
x=[1,3,2,5,6]
y=[2,3,4,5,4]
plt.plot(x,y,"*")
plt.show()
